# %% [markdown]
# # Do not change this file

# %%
import pandas as pd
import numpy as np

# %%
city_industry_matrix = pd.read_csv("/home/thrymr/Downloads/Projects/Command Center/Data/city_industry_matrix.csv")

# %%
city_industry_matrix
# Out:
#            date      city_name             industry_name  detection_count
# 0    2023-04-23      Abu Dhabi     Professional Services                2
# 1    2023-04-23         Adalaj  Hospitality & Healthcare                4
# 2    2023-04-23       Agartala     Professional Services                3
# 3    2023-04-23      Ahmedabad                   Telecom                1
# 4    2023-04-23      Ahmedabad                   IT/ITES                6
# ..          ...            ...                       ...              ...
# 537  2023-04-23  Visakhapatnam                   IT/ITES                2
# 538  2023-04-23  Visakhapatnam     Professional Services               73
# 539  2023-04-23    Yamunanagar             Manufacturing               17
# 540  2023-04-23       Yasothon     Professional Services                2
# 541  2023-04-23      Yongin-si     Professional Services               10
#
# [542 rows x 4 columns]

# %%
city_industry_matrix_list = city_industry_matrix.columns.to_list()

# %%
city_industry_matrix_list
# Out:
# ['date', 'city_name', 'industry_name', 'detection_count']

# %%
cloud_lookup_stats = pd.read_csv("/home/thrymr/Downloads/Projects/Command Center/Data/cloud_lookup_stats.csv")

# %%
cloud_lookup_stats
# Out:
#          date  url_lookup_count  file_lookup_count
# 0  2023-04-23          50002736           10002736
# 1  2023-04-24          55002736           12002736
# 2  2023-04-25          55002736           22002736
# 3  2023-04-26          65002736           19002736
# 4  2023-04-27          45002736           22002736

# %%
cloud_lookup_stats_list = cloud_lookup_stats.columns.to_list()

# %%
daily_detection_count = pd.read_csv("/home/thrymr/Downloads/Projects/Command Center/Data/daily_detection_count.csv")

# %%
daily_detection_count
# Out:
#           date  total_engine_count  total_ngav_count  total_arw_count  \
# 0   2023-05-20             1083428          39262933             2453
# 1   2023-05-21             1173610          38282863             2216
# 2   2023-05-22             1072543          36513709             3162
# 3   2023-05-23             1126055          38904134             3542
# 4   2023-05-24             1200681          36832411             2636
# 5   2023-05-25             1162545          35618433             3957
# 6   2023-05-26             1163549          40120498             2442
# 7   2023-05-27             1124989          36886321             3824
# 8   2023-05-28             1190326          35620333             2592
# 9   2023-05-29             1196741          37316315             3561
# 10  2023-05-30             1202747          39285786             3383
#
#     total_web_security_count  uniq_engine_count  uniq_ngav_count  \
# ...

# %%
daily_detection_count_list = daily_detection_count.columns.to_list()

# %%
daily_detection_count_list
# Out:
# ['date',
#  'total_engine_count',
#  'total_ngav_count',
#  'total_arw_count',
#  'total_web_security_count',
#  'uniq_engine_count',
#  'uniq_ngav_count',
#  'uniq_arw_count',
#  'uniq_web_security_count',
#  'total_base_scanner_count',
#  'total_memory_scanner_count',
#  'total_mail_protection_count',
#  'total_boot_scanner_count',
#  'total_virus_scanner_count',
#  'uniq_memory_scanner_count',
#  'uniq_base_scanner_count',
#  'uniq_mail_protection_count',
#  'uniq_boot_scanner_count',
#  'uniq_virus_scanner_count']

# %%
endpoints_active = pd.read_csv("/home/thrymr/Downloads/Projects/Command Center/Data/endpoints_active.csv")

# %%
endpoints_active
# Out:
#            date              city_name               state_name country_name  \
# 0    2023-05-02                  Kyoto                    Kyoto        Japan
# 1    2023-05-02                 Kärdla                  Hiiumaa      Estonia
# 2    2023-05-02                 Köthen            Saxony-Anhalt      Germany
# 3    2023-05-02                   Køge                  Zealand      Denmark
# 4    2023-05-02              LaOrignal                  Ontario       Canada
# ..          ...                    ...                      ...          ...
# 890  2023-05-02             Montemagno         Province of Pisa        Italy
# 891  2023-05-02             Montemagno        Provincia di Asti        Italy
# 892  2023-05-02          Montemarciano      Provincia di Ancona        Italy
# 893  2023-05-02             Montemurlo       Provincia di Prato        Italy
# 894  2023-05-02  Montenero di Bisaccia  Provincia di Campobasso        Italy
#
#      active_endpoint_count
# ...

# %%
endpoints_active_list = endpoints_active.columns.to_list()

# %%
endpoints_active_list
# Out:
# ['date', 'city_name', 'state_name', 'country_name', 'active_endpoint_count']

# %%
lab_feed_count = pd.read_csv("/home/thrymr/Downloads/Projects/Command Center/Data/lab_feed_count.csv")

# %%
lab_feed_count
# Out:
#           date feed_geo_location  sample_count  url_count  source_city  \
# 0   2023-05-20  20.4143, 72.8324        358430          0          NaN
# 1   2023-05-20  27.0834, 93.6097        120199          0          NaN
# 2   2023-05-20  11.6661, 92.7464         96288          0          NaN
# 3   2023-05-20  23.7289, 92.7179         27961          0          NaN
# 4   2023-05-20  27.3257, 88.6122         12280          0          NaN
# 5   2023-05-20  15.5017, 73.8225          8983          0          NaN
# 6   2023-05-20  25.5689, 91.8831          2803          0          NaN
# 7   2023-05-20  24.8086, 93.9418          2602          0          NaN
# 8   2023-05-20   23.1701, 79.957          2195          0          NaN
# 9   2023-05-20   12.9172, 74.856          1439          0          NaN
# 10  2023-05-20  25.3144, 83.0053          1273          0          NaN
# 11  2023-05-20  34.0857, 74.8055           794          0          NaN
# ...

# %%
lab_feed_count_list = lab_feed_count.columns.to_list()

# %%
lab_feed_count_list
# Out:
# ['date',
#  'feed_geo_location',
#  'sample_count',
#  'url_count',
#  'source_city',
#  'source_country']

# %%
lab_hi_analysis_count = pd.read_csv("/home/thrymr/Downloads/Projects/Command Center/Data/lab_hi_analysis_count.csv")

# %%
lab_hi_analysis_count
# Out:
#          date  malware_count  clean_count  unknown_count  total_count
# 0  2023-05-24             20            0              2           22
# 1  2023-05-25             25            1              4           30
# 2  2023-05-26             21            0              3           24
# 3  2023-05-27             28            2              7           37
# 4  2023-05-28             17            0              1           18

# %%
lab_hi_analysis_count_list = lab_hi_analysis_count.columns.to_list()

# %%
lab_hi_analysis_count_list
# Out:
# ['date', 'malware_count', 'clean_count', 'unknown_count', 'total_count']

# %%
lab_malware_classification = pd.read_csv("/home/thrymr/Downloads/Projects/Command Center/Data/lab_malware_classification.csv")

# %%
lab_malware_classification
# Out:
#          date  malware_count  pua_count  adware_count  unknown_count  \
# 0  2023-05-20           2078       1032           893          28802
# 1  2023-05-24           2112        932           763          24869
# 2  2023-05-25           1934        934           837          24604
# 3  2023-05-26           1834       1134           394          22589
# 4  2023-05-27           2232        833           563          22656
#
#    clean_count  total_count
# 0          156       280838
# 1          182       296025
# 2          176       280205
# 3          103       290985
# 4          190       286259

# %%
lab_malware_classification_list = lab_malware_classification.columns.to_list()

# %%
lab_malware_classification_list
# Out:
# ['date',
#  'malware_count',
#  'pua_count',
#  'adware_count',
#  'unknown_count',
#  'clean_count',
#  'total_count']

# %%
lab_ml_url_classification = pd.read_csv("/home/thrymr/Downloads/Projects/Command Center/Data/lab_ml_url_classification.csv")

# %%
lab_ml_url_classification
# Out:
#          date  count
# 0  2023-05-18  90653
# 1  2023-05-19  70233
# 2  2023-05-20  73495
# 3  2023-05-21  71167
# 4  2023-05-22  91645
# 5  2023-05-23  85422
# 6  2023-05-24  91080
# 7  2023-05-25  54562
# 8  2023-05-26  80864
# 9  2023-05-27  81306

# %%
lab_ml_url_classification_list = lab_ml_url_classification.columns.to_list()

# %%
lab_ml_url_classification_list
# Out:
# ['date', 'count']

# %%
lab_signature_count = pd.read_csv("/home/thrymr/Downloads/Projects/Command Center/Data/lab_signature_count.csv")

# %%
lab_signature_count
# Out:
#          date  apex_count  sml_count  nonpe_count
# 0  2023-05-05         154        510       177329
# 1  2023-05-06         155        533       192173
# 2  2023-05-07         196        706       198773
# 3  2023-05-08         138        651       190843
# 4  2023-05-09         139        602       197664
# 5  2023-05-10         149        543       164829
# 6  2023-05-11         160        836       165806
# 7  2023-05-12         160        711       194037
# 8  2023-05-13         173        984       170735
# 9  2023-05-14         119        830       153568

# %%
lab_signature_count_list = lab_signature_count.columns.to_list()

# %%
lab_signature_count_list
# Out:
# ['date', 'apex_count', 'sml_count', 'nonpe_count']

# %%
lab_update_info = pd.read_csv("/home/thrymr/Downloads/Projects/Command Center/Data/lab_update_info.csv")

# %%
lab_update_info
# Out:
#           date                  vdb            update_type
# 0   2023-05-01  2023-05-01 00:02:00                 ENGINE
# 1   2023-05-01  2023-05-01 08:49:00                 ENGINE
# 2   2023-05-01  2023-05-01 08:40:00  Vulnerability Scanner
# 3   2023-05-01  2023-05-01 11:52:00                 ENGINE
# 4   2023-05-01  2023-05-01 18:06:00                 ENGINE
# ..         ...                  ...                    ...
# 66  2023-05-18  2023-05-18 16:14:00  Vulnerability Scanner
# 67  2023-05-18  2023-05-18 20:16:00                 ENGINE
# 68  2023-05-19  2023-05-19 00:03:00                Product
# 69  2023-05-19  2023-05-19 08:14:00  Vulnerability Scanner
# 70  2023-05-19  2023-05-19 09:35:00                 ENGINE
#
# [71 rows x 3 columns]

# %%
lab_update_info_list = lab_update_info.columns.to_list()

# %%
lab_update_info_list
# Out:
# ['date', 'vdb', 'update_type']

# %%
platform_detection_matrix = pd.read_csv("/home/thrymr/Downloads/Projects/Command Center/Data/platform_detection_matrix.csv")

# %%
platform_detection_matrix
# Out:
#             date       platform_name  ngav_detection_count  \
# 0     2023-04-23  Windows 8.1 64 bit                   NaN
# 1     2023-04-23   Windows 10 64 bit                   NaN
# 2     2023-04-23   Windows 10 64 bit                   NaN
# 3     2023-04-23         Windows 8.1                   NaN
# 4     2023-04-23  Windows 8.1 64 bit                   NaN
# ...          ...                 ...                   ...
# 3664  2023-04-23   Windows 10 64 bit                   NaN
# 3665  2023-04-23   Windows 10 64 bit                   NaN
# 3666  2023-04-23   Windows 10 64 bit                   NaN
# 3667  2023-04-23   Windows 10 64 bit                   NaN
# 3668  2023-04-23    Windows 7 64 bit                   NaN
#
#       arw_detection_count  network_detection_count  engine_detection_count  \
# 0                     NaN                      NaN                     NaN
# 1                     NaN                      NaN                     NaN
# ...

# %%
platform_detection_matrix_list = platform_detection_matrix.columns.to_list()

# %%
platform_detection_matrix_list
# Out:
# ['date',
#  'platform_name',
#  'ngav_detection_count',
#  'arw_detection_count',
#  'network_detection_count',
#  'engine_detection_count',
#  'protected_endpoint_count']

# %%
top_detections_daily = pd.read_csv("/home/thrymr/Downloads/Projects/Command Center/Data/top_detections_daily.csv")

# %%
top_detections_daily
# Out:
#          date top_cities  top_city_counts            top_cves  \
# 0  2023-05-02     Mumbai            58905         EternalBlue
# 1  2023-05-02    Kolkata            45898    CVE-2017-0147-EC
# 2  2023-05-02       Pune            38046            Autoblue
# 3  2023-05-02  New Delhi            34299           URSNIF!AP
# 4  2023-05-02      Delhi            33937   CryptojackingDDoS
# 5  2023-05-02      Surat            31983      MaliciousIP!AR
# 6  2023-05-02  Bengaluru            24100  EternalSynergyLeak
#
#    top_cves_counts            top_industries  top_industry_counts  \
# 0           825608     Professional Services                40106
# 1           797339             Manufacturing                31481
# 2           307132                 Education                22310
# 3            89234                Government                16727
# 4            76200  Hospitality & Healthcare                 9179
# 5            71952                   IT/ITES                 7884
# ...

# %%
top_detections_daily_list = top_detections_daily.columns.to_list()

# %%
top_detections_daily_list
# Out:
# ['date',
#  'top_cities',
#  'top_city_counts',
#  'top_cves',
#  'top_cves_counts',
#  'top_industries',
#  'top_industry_counts',
#  'top_ips',
#  'top_ip_counts',
#  'top_process',
#  'top_process_counts',
#  'top_ransomware',
#  'top_ransomware_counts',
#  'top_threats',
#  'top_threat_counts',
#  'top_states',
#  'top_state_counts',
#  'top_tactics',
#  'top_tactics_count']

# %%
url_classification_count = pd.read_csv("/home/thrymr/Downloads/Projects/Command Center/Data/url_classification_count.csv")

# %%
url_classification_count
# Out:
#          date  malicious_count  phishing_count  clean_count  unknown_count
# 0  2023-05-23           160982             158          507           9478
# 1  2023-05-24           168182             126          506          10023
# 2  2023-05-25           174240             176          406           5303
# 3  2023-05-26           157023             251          293           5153
# 4  2023-05-27           176793             260          582           6113
# 5  2023-05-28           194610             191          305          10637
# 6  2023-05-29           170493             147          218           7187
# 7  2023-05-30           132779             142          489           9680
# 8  2023-05-31           188133             213          331           6881

# %%
url_classification_count_list = url_classification_count.columns.to_list()

# %%
url_classification_count_list
# Out:
# ['date', 'malicious_count', 'phishing_count', 'clean_count', 'unknown_count']

# %%
url_detection_count = pd.read_csv("/home/thrymr/Downloads/Projects/Command Center/Data/url_detection_count.csv")

# %%
url_detection_count
# Out:
#          date  malicious_count  phishing_count  parental_count
# 0  2023-05-02          1078881           17810           16461
# 1  2023-05-03          1161104           17811           19702
# 2  2023-05-04           974491           13305           19153
# 3  2023-05-05           941227           18692           16910
# 4  2023-05-06          1009934           15897           17949
# 5  2023-05-07           905873           16389           16375
# 6  2023-05-08           969532           17167           16718
# 7  2023-05-09          1138910           14734           19991
# 8  2023-05-10           965111           17350           17861
# 9  2023-05-11           935822           12283           16412

# %%
url_detection_count_list = url_detection_count.columns.to_list()

# %%
url_detection_count_list
# Out:
# ['date', 'malicious_count', 'phishing_count', 'parental_count']

# %% [markdown]
# ## Do not change this file
